# %% [markdown]
# # Image denoising

# %%
from utils import (
    prox_mcp, mcp, mcp_torch, lmo_spectral, lmo_nuclear, TV, TV_adj, TV_torch, 
    prox_l1, lmo_block_l1, lmo_l2
)

from BCD import load_dataset

from epoch_vs_regular import (
    run_experiment, plot_scaling, plot_images, plot_loss, plot_ssims,
    plot_primal_gap_and_penalty, plot_smoothing_loss
)

import numpy as np
import matplotlib.pyplot as plt
import torch

noise_level = 0.05
# lam = 0.05#2*noise_level
lam = 0.05
mu = 2.#3.

dataset = 'camera'
# dataset = "spectrometer"
# dataset = "olivetti" 
# dataset = "football"
# dataset = "miserables"
# dataset = "low_rank_synthetic"

K = 10#_000 if dataset == 'olivetti' else 10_000
store_WH_every = 100 if dataset == 'olivetti' else 1
def g(X):
    Px, Py = X
    return np.sum(mcp(Px, lam, mu)) + np.sum(mcp(Py, lam, mu))
    # return np.sum(np.abs(Px)) + np.sum(np.abs(Py))

def g_torch(X):
    Px, Py = X
    return torch.sum(mcp_torch(Px, lam, mu)) + torch.sum(mcp_torch(Py, lam, mu))
    # return torch.sum(torch.abs(Px)) + torch.sum(torch.abs(Py))

prox = lambda x, b : prox_mcp(x, b, lam, mu)
# prox = prox_l1
T = TV
T_adj = lambda x : TV_adj(x[0], x[1])
# lmo = lambda M : lmo_spectral(M, 1., 6)
# lmo = lambda M : lmo_block_l1(M, 1.)
lmo = lambda M : lmo_l2(M, 1.)
# lmo = lambda M : lmo_nuclear(M, 1.)
comment = ""
save = False
scale = False

# %% [markdown]
# ## Add noise to the image

# %%
from utils import noisy_image
# import odl

D = load_dataset(dataset)
# data_odl = odl.phantom.white_noise(D, mean=D, stddev=20, seed=1807)

print(D.min(), D.max())

if scale:
    # Min-Max Scaling
    min_vals = D.min()
    max_vals = D.max()

    D = (D - min_vals) / (max_vals - min_vals)

img = plt.imshow(D)
img.set_cmap('gray')
plt.axis('off')
plt.title('Original')
plt.show()

# Add gaussian noise to the image
Y_gaussian = noisy_image(D, noise_level=noise_level)

img = plt.imshow(Y_gaussian)
img.set_cmap('gray')
plt.axis('off')
plt.title(f'Noisy gaussian sigma = {noise_level}')
plt.show()

# Add salt and pepper noise
Y_salt_and_pepper = noisy_image(D, noise_type='salt_and_pepper', noise_level=0.02)

img = plt.imshow(Y_salt_and_pepper) 
img.set_cmap('gray')
plt.axis('off')
plt.title('Noisy salt and pepper noise_level = 0.02')
plt.show()
# Out:
# 0.008465512696419247 0.9994933599059728

# %% [markdown]
# ## Experiments for gaussian noise

# %%
X = D + np.random.randn(*D.shape) * 0.1
px, py = TV(X)
print(px.shape, py.shape)
# Out:
# (256, 256) (256, 256)

# %%
T_adj(prox(T(X), 0.1)).shape
# Out:
# (256, 256)

# %%
results = run_experiment(
    dataset, 
    T = T,
    T_torch = TV_torch,
    T_adj = T_adj,
    # noise_type = 'salt_and_pepper',
    noise_type = 'gaussian',
    noise_level = noise_level,
    K = K, 
    g = g,
    g_torch = g_torch,
    prox = prox,    
    lmo = lmo,
    comment = comment,
    save = save,
    scale = scale,
)
# Out:
#   0%|          | 0/1024 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 results = run_experiment(
#       2     dataset,
#       3     T = T,
#       4     T_torch = TV_torch,
#
# File ~/Research/MoreauFW/melmo/MELMO/epoch_vs_regular.py:71, in run_experiment(dataset_name, noise_type, noise_level, T, T_torch, T_adj, K, g, g_torch, prox, lmo, comment, save, scale)
#      67 results['F_min'] = F_min
#      70 # Running the experiments
# ---> 71 loss_NSD, penalty_NSD, ssims_NSD, dist_W_prox, WHs_NSD, grad_norms_NSD = run_melmo2(
#      72     D, g = g, prox = prox, T = T, T_adj = T_adj, max_iter = 2**K, lmo = lambda M : lmo_spectral(M, 1., 6),
#      73     original = Y,
#      74 )
#      75 print(f'melmo (regular) loss: {loss_NSD[-1]}')
#      76 results['melmo (regular)'] = {
#      77     'loss': loss_NSD,
#      78     'penalty': penalty_NSD,
#    (...)     82     'grad_norms': grad_norms_NSD,
#      83 }
#
# File ~/Research/MoreauFW/melmo/MELMO/runs.py:157, in run_melmo2(Y, g, T, T_adj, prox, lmo, gamma, beta, p, q, e, max_iter, fixed_steps, original, norm_type, dual_norm_type)
#     155 TW = T(W)
#     156 penalty[t] = g(TW)
# --> 157 g_W = -2*D + T_adj(grad_g(TW, beta_t))
#     158 W = update(g_W, lmo, W, gamma_t)
#     159 grad_norms[t] = np.linalg.norm(g_W, dual_norm_type)
#
# File ~/Research/MoreauFW/melmo/MELMO/runs.py:136, in run_melmo2.<locals>.<lambda>(x, b)
#     116 def run_melmo2(
#     117     Y : np.ndarray,
#     118     g  : Callable,
#    (...)    133     # store_WH_every = 1,
#     134     ):
# --> 136     grad_g = lambda x, b : grad_gb(x, prox, b)
#     138     # W = np.random.randn(Y.shape[0], Y.shape[1])
#     139     W = Y.copy()
#
# File ~/Research/MoreauFW/melmo/MELMO/utils.py:347, in grad_gb(x, prox, b)
#     346 def grad_gb(x, prox, b):
# --> 347     return (x - prox(x, b))/b
#
# Cell In[1], line 41, in <lambda>(x, b)
# ---> 41 prox = lambda x, b : prox_mcp(x, b, lam, mu)
#
# File ~/Research/MoreauFW/melmo/MELMO/utils.py:319, in prox_mcp(x, b, lam, mu)
#     299 """
#     300 Numba-compatible proximal operator for MCP penalty.
#     301
#    (...)    316     Proximal mapping result with same shape as x
#     317 """
#     318 if mu <= b:
# --> 319     raise ValueError("Need mu > b")
#     321 # Handle scalar input directly
#     322 if np.isscalar(x):
#
# ValueError: Need mu > b

# %%
plot_images(results)

# %%
plot_loss(results)
# Out:
# melmo (regular) : 2.791e-03
# melmo (epochs) : 2.906e-03

# %%
plot_primal_gap_and_penalty(results)
# Out:
# melmo (regular) : 1.621e+02
# melmo (epochs) : 1.633e+02
# VS : 9.987e+01
# melmo (p = 2/3, q = 1/3) : 9.850e+01

# %%
plot_ssims(results)
# Out:
# melmo (regular) : 6.636e-01
# melmo (epochs) : 6.813e-01

# %%
plot_smoothing_loss(results)
# Out:
# melmo (regular) : 2.970e-04
# melmo (epochs) : 1.264e-01

# %%
from epoch_vs_regular import plot_norms
plot_norms(results)
# Out:
# melmo (regular) : 2.401e+02
# melmo (epochs) : 8.433e-01
